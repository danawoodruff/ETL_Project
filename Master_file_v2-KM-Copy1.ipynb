# %% [markdown]
# # ETL Project - Team

# %% [markdown]
# ## Objective
# •	Obtain resources from real estate site and school accountability website to extract, transform, and load csv files to conduct an informative analysis in the future.
#
#     - Help our clients to find the perfect house with the perfect school

# %% [markdown]
# ## Type DataBase
# •	SQL Postgres

# %% [markdown]
# ## HAR Data

# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
from secrets import username, password

# %%
# store CSV into DF
csv_file= "./Resources/HAR.csv"
customer_data_df= pd.read_csv(csv_file)
customer_data_df.head()
# Out:
#         MLS  Street_Number  Street_Name     City    Zip  County   Subdivision  \
# 0  70161219           1747  Forest Hill  Houston  77023  Harris   Forest Hill
# 1  17580127           1911     Pasadena  Houston  77023  Harris   Forest Hill
# 2  35404452           1931   Santa Rosa  Houston  77023  Harris   Forest Hill
# 3  12503971           2022  Forest Hill  Houston  77023  Harris   Forest Hill
# 4  32263872           6707     Avenue I  Houston  77011  Harris  Central Park
#
#        Home_Type  Year_Built  Bedrooms  ...                             Style  \
# 0  Single-Family        1952         3  ...                       Traditional
# 1  Single-Family        1949         2  ...                       Traditional
# 2  Single-Family        1949         3  ...  Contemporary/Modern, Traditional
# 3  Single-Family        1938         4  ...                       Traditional
# 4  Single-Family        2020         3  ...                       Traditional
#
#    List_Price  Market_Area                  Area  DOM  CDOM   List_Date  \
# 0      255000            4  East End Revitalized    5     5    2/1/2021
# 1      324900            4  East End Revitalized   74    74  11/24/2020
# 2      319000            4  East End Revitalized   53    53  12/11/2020
# 3      399000            4  East End Revitalized    3     3    2/3/2021
# 4      280990            4       University Area  134   251   9/25/2020
#
#    School_District          Elementary         High_School
# 0     27 - Houston  BRISCOE ELEMENTARY  AUSTIN HIGH SCHOOL
# 1     27 - Houston  BRISCOE ELEMENTARY  AUSTIN HIGH SCHOOL
# 2     27 - Houston  BRISCOE ELEMENTARY  AUSTIN HIGH SCHOOL
# 3     27 - Houston  BRISCOE ELEMENTARY  AUSTIN HIGH SCHOOL
# 4     27 - Houston  BRISCOE ELEMENTARY  AUSTIN HIGH SCHOOL
#
# [5 rows x 28 columns]

# %%
# Total info
customer_data_df.shape
# Out:
# (3241, 28)

# %%
# Columns list
customer_data_df.columns
# Out:
# Index(['MLS', 'Street_Number', 'Street_Name', 'City', 'Zip', 'County',
#        'Subdivision', 'Home_Type', 'Year_Built', 'Bedrooms', 'Full_Baths',
#        'Half_Baths', 'Total_Baths', 'Room_Count', 'Fireplaces', 'Stories',
#        'Pool_Private', 'Garages', 'Style', 'List_Price', 'Market_Area', 'Area',
#        'DOM', 'CDOM', 'List_Date', 'School_District', 'Elementary',
#        'High_School'],
#       dtype='object')

# %%
# Navigate a single column
customer_data_df['Fireplaces']
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 3236    0
# 3237    0
# 3238    0
# 3239    0
# 3240    1
# Name: Fireplaces, Length: 3241, dtype: int64

# %%
# Replace null values with "0"
customer_data_df['Fireplaces']= customer_data_df['Fireplaces'].fillna(0)

# %%
# Check replacement
customer_data_df['Fireplaces']
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 3236    0
# 3237    0
# 3238    0
# 3239    0
# 3240    1
# Name: Fireplaces, Length: 3241, dtype: int64

# %%
# Replace null values with "0"
customer_data_df['Garages']= customer_data_df['Garages'].fillna(0)

# %%
# Checking unique values
customer_data_df.nunique()
# Out:
# MLS                3241
# Street_Number      2151
# Street_Name        1841
# City                 10
# Zip                  67
# County                3
# Subdivision        1699
# Home_Type             1
# Year_Built          112
# Bedrooms             11
# Full_Baths           10
# Half_Baths            7
# Total_Baths          38
# Room_Count           26
# Fireplaces            8
# Stories               5
# Pool_Private          2
# Garages              16
# Style                79
# List_Price         1228
# Market_Area          18
# Area                 58
# DOM                 355
# CDOM                572
# List_Date           359
# School_District       2
# Elementary          167
# High_School          36
# dtype: int64

# %%
# Checking unique values
customer_data_df.nunique().count()
# Out:
# 28

# %%
# isna/isnull
customer_data_df.isna().sum()
# Out:
# MLS                0
# Street_Number      0
# Street_Name        0
# City               0
# Zip                0
# County             0
# Subdivision        1
# Home_Type          0
# Year_Built         0
# Bedrooms           0
# Full_Baths         0
# Half_Baths         0
# Total_Baths        0
# Room_Count         0
# Fireplaces         0
# Stories            0
# Pool_Private       0
# Garages            0
# Style              0
# List_Price         0
# Market_Area        0
# Area               0
# DOM                0
# CDOM               0
# List_Date          0
# School_District    0
# Elementary         0
# High_School        0
# dtype: int64

# %%
# Data types
customer_data_df.dtypes
# Out:
# MLS                  int64
# Street_Number        int64
# Street_Name         object
# City                object
# Zip                  int64
# County              object
# Subdivision         object
# Home_Type           object
# Year_Built           int64
# Bedrooms             int64
# Full_Baths           int64
# Half_Baths           int64
# Total_Baths        float64
# Room_Count           int64
# Fireplaces           int64
# Stories              int64
# Pool_Private          bool
# Garages              int64
# Style               object
# List_Price           int64
# Market_Area          int64
# Area                object
# DOM                  int64
# CDOM                 int64
# List_Date           object
# School_District     object
# Elementary          object
# High_School         object
# dtype: object

# %%
# Create new table
HAR_df= customer_data_df
HAR_df.head()
# Out:
#         MLS  Street_Number  Street_Name     City    Zip  County   Subdivision  \
# 0  70161219           1747  Forest Hill  Houston  77023  Harris   Forest Hill
# 1  17580127           1911     Pasadena  Houston  77023  Harris   Forest Hill
# 2  35404452           1931   Santa Rosa  Houston  77023  Harris   Forest Hill
# 3  12503971           2022  Forest Hill  Houston  77023  Harris   Forest Hill
# 4  32263872           6707     Avenue I  Houston  77011  Harris  Central Park
#
#        Home_Type  Year_Built  Bedrooms  ...                             Style  \
# 0  Single-Family        1952         3  ...                       Traditional
# 1  Single-Family        1949         2  ...                       Traditional
# 2  Single-Family        1949         3  ...  Contemporary/Modern, Traditional
# 3  Single-Family        1938         4  ...                       Traditional
# 4  Single-Family        2020         3  ...                       Traditional
#
#    List_Price  Market_Area                  Area  DOM  CDOM   List_Date  \
# 0      255000            4  East End Revitalized    5     5    2/1/2021
# 1      324900            4  East End Revitalized   74    74  11/24/2020
# 2      319000            4  East End Revitalized   53    53  12/11/2020
# 3      399000            4  East End Revitalized    3     3    2/3/2021
# 4      280990            4       University Area  134   251   9/25/2020
#
#    School_District          Elementary         High_School
# 0     27 - Houston  BRISCOE ELEMENTARY  AUSTIN HIGH SCHOOL
# 1     27 - Houston  BRISCOE ELEMENTARY  AUSTIN HIGH SCHOOL
# 2     27 - Houston  BRISCOE ELEMENTARY  AUSTIN HIGH SCHOOL
# 3     27 - Houston  BRISCOE ELEMENTARY  AUSTIN HIGH SCHOOL
# 4     27 - Houston  BRISCOE ELEMENTARY  AUSTIN HIGH SCHOOL
#
# [5 rows x 28 columns]

# %%
HAR_df.to_csv("./Resources/clean_har.csv", index = False)

# %% [markdown]
# ## TEA Data

# %%
# store CSV into DF
csv_file= "./Resources/School_rating.csv"
old_school_rating_df= pd.read_csv(csv_file)
old_school_rating_df.head()
# Out:
#    Campus_Number                School    District  Yrs_Unacceptable  \
# 0      101902001    ALDINE HIGH SCHOOL  ALDINE ISD                 0
# 1      101902099      ALDINE J J A E P  ALDINE ISD                 0
# 2      101902041         ALDINE MIDDLE  ALDINE ISD                 0
# 3      101902101      ANDERSON ACADEMY  ALDINE ISD                 1
# 4      101902015  AVALOS P-TECH SCHOOL  ALDINE ISD                 0
#
#   Rating_2019
# 0           C
# 1   Not Rated
# 2           D
# 3           F
# 4   Not Rated

# %%
a_school_rating_df= old_school_rating_df.rename(columns= {"Rating_2019": "Rating"})
a_school_rating_df
# Out:
#      Campus_Number                      School    District  Yrs_Unacceptable  \
# 0        101902001          ALDINE HIGH SCHOOL  ALDINE ISD                 0
# 1        101902099            ALDINE J J A E P  ALDINE ISD                 0
# 2        101902041               ALDINE MIDDLE  ALDINE ISD                 0
# 3        101902101            ANDERSON ACADEMY  ALDINE ISD                 1
# 4        101902015        AVALOS P-TECH SCHOOL  ALDINE ISD                 0
# ..             ...                         ...         ...               ...
# 650      101919051  SPRINGWOODS VILLAGE MIDDLE  SPRING ISD                 0
# 651      101919047     STELLE CLAUGHTON MIDDLE  SPRING ISD                 1
# 652      101919045          TWIN CREEKS MIDDLE  SPRING ISD                 0
# 653      101919002       WESTFIELD HIGH SCHOOL  SPRING ISD                 0
# 654      888888882         MCELWAIN ELEMENTARY    KATY ISD                 0
#
#         Rating
# 0            C
# 1    Not Rated
# 2            D
# 3            F
# 4    Not Rated
# ..         ...
# 650  Not Rated
# 651          F
# 652          C
# 653          D
# 654  Not Rated
#
# [655 rows x 5 columns]

# %%
a_school_rating_df['Year']= 2019
a_school_rating_df
# Out:
#      Campus_Number                      School    District  Yrs_Unacceptable  \
# 0        101902001          ALDINE HIGH SCHOOL  ALDINE ISD                 0
# 1        101902099            ALDINE J J A E P  ALDINE ISD                 0
# 2        101902041               ALDINE MIDDLE  ALDINE ISD                 0
# 3        101902101            ANDERSON ACADEMY  ALDINE ISD                 1
# 4        101902015        AVALOS P-TECH SCHOOL  ALDINE ISD                 0
# ..             ...                         ...         ...               ...
# 650      101919051  SPRINGWOODS VILLAGE MIDDLE  SPRING ISD                 0
# 651      101919047     STELLE CLAUGHTON MIDDLE  SPRING ISD                 1
# 652      101919045          TWIN CREEKS MIDDLE  SPRING ISD                 0
# 653      101919002       WESTFIELD HIGH SCHOOL  SPRING ISD                 0
# 654      888888882         MCELWAIN ELEMENTARY    KATY ISD                 0
#
#         Rating  Year
# 0            C  2019
# 1    Not Rated  2019
# 2            D  2019
# 3            F  2019
# 4    Not Rated  2019
# ..         ...   ...
# 650  Not Rated  2019
# 651          F  2019
# 652          C  2019
# 653          D  2019
# 654  Not Rated  2019
#
# [655 rows x 6 columns]

# %%
school_rating_df= a_school_rating_df
school_rating_df
# Out:
#      Campus_Number                      School    District  Yrs_Unacceptable  \
# 0        101902001          ALDINE HIGH SCHOOL  ALDINE ISD                 0
# 1        101902099            ALDINE J J A E P  ALDINE ISD                 0
# 2        101902041               ALDINE MIDDLE  ALDINE ISD                 0
# 3        101902101            ANDERSON ACADEMY  ALDINE ISD                 1
# 4        101902015        AVALOS P-TECH SCHOOL  ALDINE ISD                 0
# ..             ...                         ...         ...               ...
# 650      101919051  SPRINGWOODS VILLAGE MIDDLE  SPRING ISD                 0
# 651      101919047     STELLE CLAUGHTON MIDDLE  SPRING ISD                 1
# 652      101919045          TWIN CREEKS MIDDLE  SPRING ISD                 0
# 653      101919002       WESTFIELD HIGH SCHOOL  SPRING ISD                 0
# 654      888888882         MCELWAIN ELEMENTARY    KATY ISD                 0
#
#         Rating  Year
# 0            C  2019
# 1    Not Rated  2019
# 2            D  2019
# 3            F  2019
# 4    Not Rated  2019
# ..         ...   ...
# 650  Not Rated  2019
# 651          F  2019
# 652          C  2019
# 653          D  2019
# 654  Not Rated  2019
#
# [655 rows x 6 columns]

# %%
school_rating_df.to_csv('./Resources/clean_ratings.csv', index = False)

# %%
# Duplicate School
dupl_school_rating= school_rating_df.pivot_table(index= ['School'], aggfunc= 'size')
print(dupl_school_rating)
# Out:
# School
# ACADEMY OF CHOICE                     1
# ADAM ELEMENTARY                       1
# ADAMS J H                             1
# ALAMO ELEMENTARY                      1
# ALCOTT ELEMENTARY                     1
#                                      ..
# YOUNG ELEMENTARY                      1
# YOUNG LEARNERS                        1
# YOUNG SCHOLARS ACADEMY FOR EXCELLE    1
# YOUNG WOMEN'S COLLEGE PREP ACADEMY    1
# ZELMA HUTSELL ELEMENTARY              1
# Length: 655, dtype: int64

# %%
# Duplicate School sorting descending
dupl_school_rating.sort_values(ascending=False)
# Out:
# School
# ACADEMY OF CHOICE                1
# PATTERSON ELEMENTARY             1
# NORTHSIDE HIGH SCHOOL            1
# NOTTINGHAM COUNTRY ELEMENTARY    1
# NOTTINGHAM ELEMENTARY            1
#                                 ..
# GRAY ELEMENTARY                  1
# GREEN VALLEY ELEMENTARY          1
# GREENSPOINT ELEMENTARY           1
# GREGG ELEMENTARY                 1
# ZELMA HUTSELL ELEMENTARY         1
# Length: 655, dtype: int64

# %% [markdown]
# # Load to SQL

# %%
# Connect to local database
rds_connection_string = f"{username}:{password}@localhost:5432/etlproject_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Check for tables
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  database "etlproject_db" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-23-73dc095f7130> in <module>
#       1 # Check for tables
# ----> 2 engine.table_names()
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2314         """
#    2315
# -> 2316         with self._optional_conn_ctx_manager(connection) as conn:
#    2317             return self.dialect.get_table_names(conn, schema)
#    2318
#
# ~\anaconda3\envs\sqlalchemy\lib\contextlib.py in __enter__(self)
#     115         del self.args, self.kwds, self.func
#     116         try:
# --> 117             return next(self.gen)
#     118         except StopIteration:
#     119             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2084     def _optional_conn_ctx_manager(self, connection=None):
#    2085         if connection is None:
# -> 2086             with self._contextual_connect() as conn:
#    2087                 yield conn
#    2088         else:
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2300         return self._connection_cls(
#    2301             self,
# -> 2302             self._wrap_pool_connect(self.pool.connect, None),
#    2303             close_with_result=close_with_result,
#    2304             **kwargs
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
# -> 2339                 Connection._handle_dbapi_exception_noconnection(
#    2340                     e, dialect, self
#    2341                 )
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1581             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1582         elif should_wrap:
# -> 1583             util.raise_(
#    1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# ~\anaconda3\envs\sqlalchemy\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  database "etlproject_db" does not exist
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# Use pandas to load csv converted DataFrame into database table 1 school_rating_df
school_rating_df.to_sql(name='school_rating', con=engine, if_exists='append', index=False)

# %%
# Confirm data has been added by querying the school_rating table
pd.read_sql_query('select * from school_rating', con=engine).head()

# %%
# Use pandas to load csv converted DataFrame into database table 2 HAR_df
HAR_df.to_sql(name='mls', con=engine, if_exists='append', index=False)

# %%
# Confirm data has been added by querying the mls table
pd.read_sql_query('select * from mls', con=engine).head()
